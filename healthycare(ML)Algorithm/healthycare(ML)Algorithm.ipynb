# %% [markdown]
# <h1> Healthy Care

# %%
# import liberaries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('healthcare_dataset.csv')
df
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0             1/31/2024     Matthew Smith               Sons and Miller
# ...

# %%
df.shape
# Out:
# (55500, 15)

# %%
df.dtypes
# Out:
# Name                   object
# Age                     int64
# Gender                 object
# Blood Type             object
# Medical Condition      object
# Date of Admission      object
# Doctor                 object
# Hospital               object
# Insurance Provider     object
# Billing Amount        float64
# Room Number             int64
# Admission Type         object
# Discharge Date         object
# Medication             object
# Test Results           object
# dtype: object

# %%
df.describe()
# Out:
#                 Age  Billing Amount   Room Number
# count  55500.000000    55500.000000  55500.000000
# mean      51.539459    25539.316097    301.134829
# std       19.602454    14211.454431    115.243069
# min       13.000000    -2008.492140    101.000000
# 25%       35.000000    13241.224655    202.000000
# 50%       52.000000    25538.069380    302.000000
# 75%       68.000000    37820.508432    401.000000
# max       89.000000    52764.276740    500.000000

# %%
df.describe(include='object')
# Out:
#                Name Gender Blood Type Medical Condition Date of Admission  \
# count         55500  55500      55500             55500             55500
# unique        49992      2          8                 6              1827
# top     DAvId muNoZ   Male         A-         Arthritis         3/16/2024
# freq              3  27774       6969              9308                50
#
#                Doctor   Hospital Insurance Provider Admission Type  \
# count           55500      55500              55500          55500
# unique          40341      39876                  5              3
# top     Michael Smith  LLC Smith              Cigna       Elective
# freq               27         44              11249          18655
#
#        Discharge Date Medication Test Results
# count           55500      55500        55500
# unique           1856          5            3
# top         3/15/2020    Lipitor     Abnormal
# freq               53      11140        18627

# %%
df.head(2)
# Out:
#             Name  Age Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30   Male         B-            Cancer         1/31/2024
# 1   LesLie TErRy   62   Male         A+           Obesity         8/20/2019
#
#             Doctor         Hospital Insurance Provider  Billing Amount  \
# 0    Matthew Smith  Sons and Miller         Blue Cross     18856.28131
# 1  Samantha Davies          Kim Inc           Medicare     33643.32729
#
#    Room Number Admission Type Discharge Date   Medication  Test Results
# 0          328         Urgent       2/2/2024  Paracetamol        Normal
# 1          265      Emergency      8/26/2019    Ibuprofen  Inconclusive

# %%
df_gender = df.groupby('Gender')['Billing Amount'].value_counts()
df_gender
# Out:
# Gender  Billing Amount
# Female  -887.024219       2
#         -591.917419       2
#         -308.584269       2
#         -228.546854       2
#         -68.319621        2
#                          ..
# Male     51731.659880     1
#          51848.201600     1
#          52024.726440     1
#          52092.669900     1
#          52271.663750     1
# Name: count, Length: 50000, dtype: int64

# %%
df_gender_sum = df.groupby('Gender').agg({
    'Billing Amount':'sum',
    'Gender':'count'
}).sort_values('Billing Amount', ascending=False)
df_gender_sum
# Out:
#         Billing Amount  Gender
# Gender
# Male      7.112327e+08   27774
# Female    7.061993e+08   27726

# %%
df_blood = df.groupby('Blood Type')['Billing Amount'].value_counts('Blood Type', ascending=False)
df_blood
# Out:
# Blood Type  Billing Amount
# A+          -306.364925       0.000288
#             -228.546854       0.000288
#              539.514999       0.000288
#              806.541038       0.000288
#              865.720496       0.000288
#                                 ...
# O-           51119.453010     0.000145
#              51122.131010     0.000145
#              51198.118510     0.000145
#              51280.446380     0.000145
#              52024.726440     0.000145
# Name: proportion, Length: 50000, dtype: float64

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date',
#        'Medication', 'Test Results'],
#       dtype='object')

# %%
df1 = df[['Gender','Age','Medical Condition','Blood Type','Insurance Provider',
       'Billing Amount','Admission Type', 'Test Results']].copy()

# %%
df1.head()
# Out:
#    Gender  Age Medical Condition Blood Type Insurance Provider  \
# 0    Male   30            Cancer         B-         Blue Cross
# 1    Male   62           Obesity         A+           Medicare
# 2  Female   76           Obesity         A-              Aetna
# 3  Female   28          Diabetes         O+           Medicare
# 4  Female   43            Cancer        AB+              Aetna
#
#    Billing Amount Admission Type  Test Results
# 0     18856.28131         Urgent        Normal
# 1     33643.32729      Emergency  Inconclusive
# 2     27955.09608      Emergency        Normal
# 3     37909.78241       Elective      Abnormal
# 4     14238.31781         Urgent      Abnormal

# %%
df1.describe()
# Out:
#                 Age  Billing Amount
# count  55500.000000    55500.000000
# mean      51.539459    25539.316097
# std       19.602454    14211.454431
# min       13.000000    -2008.492140
# 25%       35.000000    13241.224655
# 50%       52.000000    25538.069380
# 75%       68.000000    37820.508432
# max       89.000000    52764.276740

# %%
df1.describe(include='object')
# Out:
#        Gender Medical Condition Blood Type Insurance Provider Admission Type  \
# count   55500             55500      55500              55500          55500
# unique      2                 6          8                  5              3
# top      Male         Arthritis         A-              Cigna       Elective
# freq    27774              9308       6969              11249          18655
#
#        Test Results
# count         55500
# unique            3
# top        Abnormal
# freq          18627

# %%
df1.describe().T
# Out:
#                   count          mean           std         min           25%  \
# Age             55500.0     51.539459     19.602454    13.00000     35.000000
# Billing Amount  55500.0  25539.316097  14211.454431 -2008.49214  13241.224655
#
#                         50%           75%          max
# Age                52.00000     68.000000     89.00000
# Billing Amount  25538.06938  37820.508432  52764.27674

# %% [markdown]
# <h2> Modelling

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_squared_error
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor

# %%
df1.isna().sum()
# Out:
# Gender                0
# Age                   0
# Medical Condition     0
# Blood Type            0
# Insurance Provider    0
# Billing Amount        0
# Admission Type        0
# Test Results          0
# dtype: int64

# %%
df1.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 55495    False
# 55496    False
# 55497    False
# 55498    False
# 55499    False
# Length: 55500, dtype: bool

# %%
print(df1[df1.duplicated()])
# Out:
#        Gender  Age Medical Condition Blood Type Insurance Provider  \
# 50023    Male   56         Arthritis         O+   UnitedHealthcare
# 50040    Male   26           Obesity         A-   UnitedHealthcare
# 50055  Female   55           Obesity         B-           Medicare
# 50070  Female   27         Arthritis         O+              Cigna
# 50078    Male   38         Arthritis        AB-           Medicare
# ...       ...  ...               ...        ...                ...
# 55461    Male   63            Asthma         A+           Medicare
# 55462  Female   35          Diabetes         A-   UnitedHealthcare
# 55464  Female   35           Obesity        AB-         Blue Cross
# 55484    Male   80            Cancer         O+              Cigna
# 55491  Female   47           Obesity         O+              Aetna
#
#        Billing Amount Admission Type  Test Results
# 50023    15654.830590         Urgent  Inconclusive
# 50040    38142.109680         Urgent      Abnormal
# ...

# %% [markdown]
# <h3> Get Dummy

# %%
use_dum = pd.get_dummies(df1,columns=df1.select_dtypes(include='object').columns)
use_dum
# Out:
#        Age  Billing Amount  Gender_Female  Gender_Male  \
# 0       30    18856.281310          False         True
# 1       62    33643.327290          False         True
# 2       76    27955.096080           True        False
# 3       28    37909.782410           True        False
# 4       43    14238.317810           True        False
# ...    ...             ...            ...          ...
# 55495   42     2650.714952           True        False
# 55496   61    31457.797310           True        False
# 55497   38    27620.764720           True        False
# 55498   43    32451.092360          False         True
# 55499   53     4010.134172           True        False
#
#        Medical Condition_Arthritis  Medical Condition_Asthma  \
# 0                            False                     False
# 1                            False                     False
# 2                            False                     False
# ...

# %%
use_dum.shape
# Out:
# (55500, 29)

# %% [markdown]
# <h5> Split the data into two part: train data and test data

# %%
X = use_dum.drop(columns=["Billing Amount"])
y= use_dum["Billing Amount"]

# %%
X.head()
# Out:
#    Age  Gender_Female  Gender_Male  Medical Condition_Arthritis  \
# 0   30          False         True                        False
# 1   62          False         True                        False
# 2   76           True        False                        False
# 3   28           True        False                        False
# 4   43           True        False                        False
#
#    Medical Condition_Asthma  Medical Condition_Cancer  \
# 0                     False                      True
# 1                     False                     False
# 2                     False                     False
# 3                     False                     False
# 4                     False                      True
#
#    Medical Condition_Diabetes  Medical Condition_Hypertension  \
# 0                       False                           False
# 1                       False                           False
# ...

# %%
y.head()
# Out:
# 0    18856.28131
# 1    33643.32729
# 2    27955.09608
# 3    37909.78241
# 4    14238.31781
# Name: Billing Amount, dtype: float64

# %% [markdown]
# <h2> Next, Standardize X

# %%
scaler = StandardScaler()
X_s = scaler.fit_transform(X)

# %% [markdown]
# <h3> Then split the data

# %% [markdown]
# Split W and y to: X_train, X_test,y_train,y_test

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
X_train.shape, X_test.shape, y_train.shape,y_test.shape
# Out:
# ((44400, 28), (11100, 28), (44400,), (11100,))

# %% [markdown]
# Linear Regression fit X_train and y_train to linear regression:

# %%
regression = LinearRegression()
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# <h3> Predict by the model

# %%
y_pred_linear = regression.predict(X_test)

# %%
y_pred_linear.shape
# Out:
# (11100,)

# %% [markdown]
# <h3> Find the R squared, R squared adjust, and MSE

# %% [markdown]
# <h3> R squared

# %%
r2_linear = r2_score(y_test,y_pred_linear)
r2_linear
# Out:
# -0.001085877589168005

# %% [markdown]
# <h3> R squared adjust

# %%
r2_ajust_linear = 1-(1-r2_linear)*(len(y)-1)/(len(y)-X.shape[1]-1)
r2_ajust_linear
# Out:
# -0.0015911939629940086

# %% [markdown]
# <h5> MSE

# %%
mse_linear = mean_squared_error(y_test,y_pred_linear)
mse_linear
# Out:
# 202810016.78314832

# %% [markdown]
# <h1> Decision Tree Regressor

# %%
tree = DecisionTreeRegressor()
tree.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %% [markdown]
# Predict by the model

# %%
y_pred_tree = tree.predict(X_test)
y_pred_tree
# Out:
# array([15633.979095,  5914.283318,  1993.756408, ..., 35408.6634  ,
#         3326.382675, 33646.11409 ])

# %% [markdown]
# Find the R squared, R squared adjust and mse

# %%
r2_tree = r2_score(y_test,y_pred_tree)
r2_tree
# Out:
# -0.9840793812029178

# %% [markdown]
# R squared adjust

# %%
r2_adjust_tree = 1-(1-r2_tree)*(len(y)-1)/(len(y)-X.shape[1]-1)
r2_adjust_tree
# Out:
# -0.9850808814944878

# %% [markdown]
# MSE

# %%
mse_tree = mean_squared_error(y_test,y_pred_tree)
mse_tree
# Out:
# 401954699.00135595

# %% [markdown]
# <h1> Random Forest Regression

# %% [markdown]
# for X_train and y_train to random forest regressor:

# %%
random_forest = RandomForestRegressor()
random_forest.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %% [markdown]
# predict by the model

# %%
y_pred_randf = random_forest.predict(X_test)
y_pred_randf
# Out:
# array([26070.02109135, 27162.63165639, 12017.7981632 , ...,
#        22035.65801782, 12899.98194973, 28353.5503923 ])

# %% [markdown]
# find the R squared R squared adjust and MSE

# %% [markdown]
# R squared

# %%
r2_randfor= r2_score(y_test,y_pred_randf)
r2_randfor
# Out:
# -0.09696042466967003

# %% [markdown]
# R squared adjust

# %%
r2_adjust_randf=1-(r2_randfor)*(len(y)-1)/(len(y)-X.shape[1]-1)
r2_adjust_randf
# Out:
# 1.0970093672142565

# %% [markdown]
# MSE

# %%
mse_randfor= mean_squared_error(y_test,y_pred_randf)
mse_randfor
# Out:
# 222233244.03843582

# %% [markdown]
# <h1> KNeighbor Regressor

# %% [markdown]
# fit x_train and y_train to Kneighbor regressor:

# %%
Knn = KNeighborsRegressor()
Knn.fit(X_train,y_train)
# Out:
# KNeighborsRegressor()

# %% [markdown]
# predict y the model

# %%
y_pred_knn = Knn.predict(X_test)
y_pred_knn
# Out:
# array([31106.998354 , 18015.4241906, 29756.7418292, ..., 26178.6480028,
#        28374.239767 , 22711.1154362])

# %% [markdown]
# find the R squared and R squared adjust and mse

# %% [markdown]
# R squared

# %%
r2_Knn=r2_score(y_test,y_pred_knn)
r2_Knn
# Out:
# -0.19349655357982498

# %% [markdown]
# R squared adjust

# %%
r2_adjust_knn = 1-(1-r2_Knn)*(len(y)-1)/(len(y)-X.shape[1]-1)
r2_adjust_knn
# Out:
# -0.1940989927552541

# %% [markdown]
# mse

# %%
mse_Knn =mean_squared_error(y_test,y_pred_knn)
mse_Knn
# Out:
# 241790501.17565364

# %% [markdown]
# <h2> Choose the best one among these 4 model

# %%
print(f"R^2:", r2_linear)
print(f"r2 adjust linear:", round(r2_ajust_linear,4))
print(f"MSE:", round(mse_linear,2))
# Out:
# R^2: -0.001085877589168005
# r2 adjust linear: -0.0016
# MSE: 202810016.78

# %%
print(f"R^2:", r2_tree)
print(f"r2 adjust Tree:", round(r2_adjust_tree,4))
print(f"MSE:", round(mse_tree,2))
# Out:
# R^2: -0.9840793812029178
# r2 adjust Tree: -0.9851
# MSE: 401954699.0

# %%
print(f"R^2:", r2_randfor)
print(f"r2 adjust random forest:", round(r2_adjust_randf,4))
print(f"MSE:",round(mse_randfor,2))
# Out:
# R^2: -0.09696042466967003
# r2 adjust random forest: 1.097
# MSE: 222233244.04

# %%
print(f"R^2:", r2_Knn)
print(f"r2 adjust KNeighbor:", round(r2_adjust_knn,4))
print(f"MSE:", round(mse_Knn,2))
# Out:
# R^2: -0.19349655357982498
# r2 adjust KNeighbor: -0.1941
# MSE: 241790501.18
